# %% [markdown]
# # Introduction
#
# For this investigative project, the dataset: Movies Data was selected. This particular project is being undertaken to answer questions and identify things like: the most and least popular movies, the most and least voted movies, the budget involved in producing the movies and its revenue.

# %% [markdown]
# # 1. Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1.1 Using Pandas to read the file

# %%
# Reading the file
movies_data = pd.read_csv('tmdb_movies.csv')

movies_data.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %% [markdown]
# # 2. Performing Exploratory Data Analysis

# %%
# Checking the number of rows and columns
movies_data.shape
# Out:
# (10866, 21)

# %%
movies_data.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
# Checking for null values

movies_data.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
# Checking for duplicate values

movies_data.duplicated().sum()
# Out:
# 1

# %%
# Checking for unique values
movies_data.nunique()
# Out:
# id                      10865
# imdb_id                 10855
# popularity              10814
# budget                    557
# revenue                  4702
# original_title          10571
# cast                    10719
# homepage                 2896
# director                 5067
# tagline                  7997
# keywords                 8804
# overview                10847
# runtime                   247
# genres                   2039
# production_companies     7445
# release_date             5909
# vote_count               1289
# vote_average               72
# release_year               56
# budget_adj               2614
# revenue_adj              4840
# dtype: int64

# %%
# Unique Genres
movies_data['genres'].unique()
# Out:
# array(['Action|Adventure|Science Fiction|Thriller',
#        'Adventure|Science Fiction|Thriller',
#        'Action|Adventure|Science Fiction|Fantasy', ...,
#        'Adventure|Drama|Action|Family|Foreign',
#        'Comedy|Family|Mystery|Romance',
#        'Mystery|Science Fiction|Thriller|Drama'], dtype=object)

# %% [markdown]
# # 2.1 Section Summary

# %% [markdown]
# The exploratory data analysis was performed to identify:
# 1. The number of rows and columns found in the data set
# 2. If there were any null values
# 3. If there were any unique or duplicated values and
# 4. The data types of each column
#
# Based on the results shown in the cells
# 1. The rows amounts to 10866 and the columns amount to 21
# 2. There were null values in the imbd_id, cast, homepage, director etc. and
# 3. The some rows in the data contain null values

# %% [markdown]
# # 3. Data Cleaning

# %%
# Removing Columns

movies_data.drop(['revenue_adj','budget_adj', 'vote_average','imdb_id', 'homepage'], axis=1, inplace=True)

# %%
#Checking if changes has taken effects
movies_data.columns
# Out:
# Index(['id', 'popularity', 'budget', 'revenue', 'original_title', 'cast',
#        'director', 'tagline', 'keywords', 'overview', 'runtime', 'genres',
#        'production_companies', 'release_date', 'vote_count', 'release_year'],
#       dtype='object')

# %%
# Changes takes effect
movies_data.shape
# Out:
# (10866, 16)

# %%
#Renaming Columns
movies_data.rename(columns = {'original_title': 'movie_title'}, inplace=True)

# %%
# Dropping NaN Values
movies_data.dropna()
# Out:
#            id  popularity     budget     revenue  \
# 0      135397   32.985763  150000000  1513528810
# 1       76341   28.419936  150000000   378436354
# 2      262500   13.112507  110000000   295238201
# 3      140607   11.173104  200000000  2068178225
# 4      168259    9.335014  190000000  1506249360
# ...       ...         ...        ...         ...
# 10858   31918    0.317824          0           0
# 10860    5060    0.087034          0           0
# 10862   20379    0.065543          0           0
# 10864   21449    0.064317          0           0
# 10865   22293    0.035919      19000           0
#
#                                             movie_title  \
# 0                                        Jurassic World
# 1                                    Mad Max: Fury Road
# 2                                             Insurgent
# 3                          Star Wars: The Force Awakens
# 4                                             Furious 7
# ...

# %%
# Finding movies with 0 budget
movies_data[movies_data['budget']==0]
# Out:
#            id  popularity  budget   revenue                     movie_title  \
# 30     280996    3.927333       0  29355203                      Mr. Holmes
# 36     339527    3.358321       0  22354572                          Solace
# 72     284289    2.272044       0     45895                Beyond the Reach
# 74     347096    2.165433       0         0          Mythica: The Darkspore
# 75     308369    2.141506       0         0  Me and Earl and the Dying Girl
# ...       ...         ...     ...       ...                             ...
# 10860    5060    0.087034       0         0             Carry On Screaming!
# 10861      21    0.080598       0         0              The Endless Summer
# 10862   20379    0.065543       0         0                      Grand Prix
# 10863   39768    0.065141       0         0             Beregis Avtomobilya
# 10864   21449    0.064317       0         0          What's Up, Tiger Lily?
#
# ...

# %% [markdown]
# # 3.1 Section Summary

# %% [markdown]
# Using the information obtained in the exploratory data analysis, certain decisions were made.
#
# 1. Some of which includes dropping all the null values
# 2. Deleting columns like imbd_id, homepage, vote_average, budget_adj and revenue_adj
# 3. Renaming the original_title to movie_title.
#
#
# These decisions and actions were necessary in facilitating the next stage of this project which involves performing analysis to draw certain conclusions.

# %% [markdown]
# # 4. Performing Analysis

# %%
# What Movie had the highest popularity?
maximum_popularity = movies_data[['movie_title','popularity']].max()
print(maximum_popularity)
# Out:
# movie_title     í•˜ìš¸ë§
# popularity     32.985763
# dtype: object

# %% [markdown]
# #### NOTE:
# The data set contained chinese symbols/language which could not be read by the notebook. Which is why the movie title contains characters

# %%
# What Movie had the highest vote count?
maximum_votes = movies_data[['movie_title','vote_count']].max()
print(maximum_votes)
# Out:
# movie_title    í•˜ìš¸ë§
# vote_count         9767
# dtype: object

# %%
# How much money was spent producing the most popular movie and what is its revenue
maximum_budget= movies_data[['movie_title','budget', 'revenue']].max()
print(maximum_budget)
# Out:
# movie_title      í•˜ìš¸ë§
# budget          425000000
# revenue        2781505847
# dtype: object

# %%
# What movie had the lowest popularity
minimum_popularity = movies_data[['movie_title','popularity']].min()
print(minimum_popularity)
# Out:
# movie_title    $5 a Day
# popularity     0.000065
# dtype: object

# %%
# What movie had the lowest vote count
minimum_votes = movies_data[['movie_title', 'vote_count']].min()
print(minimum_votes)
# Out:
# movie_title    $5 a Day
# vote_count           10
# dtype: object

# %%
# How much money was spent producing the least popular movie and its revenue
minimum_budget = movies_data[['movie_title','budget', 'revenue']].min()
print(minimum_budget)
# Out:
# movie_title    $5 a Day
# budget                0
# revenue               0
# dtype: object

# %% [markdown]
# # 4.1 Section Summary

# %% [markdown]
# The aim of this project was to:
# 1. Find the movie with the highest and lowest popularity
# 2. Find the movie with the highest and lowest vote counts
# 3. Find the movie with the highest and lowest budget and to
# 4. Find the movie with the highest and lowest revenue
#
# After performing the analysis, it was identified that the movie with the highest popularity and vote count, had the highest revenue. Which leads to the next section of this project (Performing Visualizations) that seeks to understand if there is a correlation between the revenue and budget.

# %% [markdown]
# # 5. Performing Visualizations

# %%
# Functions for Scatter plots

def scatterplots(x,y):
    plt.scatter(x, y);
    plt.show()

# %%
# Calling the scatterplots function for Vote Count and Population
plt.title('Correlation between Vote Counts and Population\n')
plt.xlabel('Vote Count')
plt.ylabel('Popularity')
scatterplots(movies_data['vote_count'], movies_data['popularity'])

# %%
# Is there a correlation between the budget and revenue?
# Calling the scatterplots function for Vote Count and Population
plt.title('Correlation Between Budget and Revenue\n')
plt.xlabel('Budget')
plt.ylabel('Revenue')
scatterplots(movies_data['budget'], movies_data['revenue'])

# %%
# declaring variables for maximum budgets against its revenue
max_budget = movies_data['budget'].max()
max_revenue = movies_data['revenue'].max()
budget_against_revenue = np.array([max_budget, max_revenue])

# %%
# Plotting the movie with the maximum budget against its revenue
plt.pie(budget_against_revenue, labels=chart_labels);
plt.title('Maximum Budget against its revenue')
plt.legend(loc='lower center')
plt.show()

# %%
# declaring variables for minimum budgets against its revenue
min_budget = movies_data['budget'].min()
min_revenue = movies_data['revenue'].min()
chart_labels = ['Minimum Budget', 'Minimum Revenue']
minimum_budget_against_revenue = np.array([min_budget,min_revenue])
print(minimum_budget_against_revenue)
# Out:
# [0 0]

# %% [markdown]
# #### Plotting the movie with the maximum budget against its revenue
#
# Since the result for this is Zero it didn't seem wise to make this plot

# %% [markdown]
# # 5.1 Conclusion

# %% [markdown]
# According to the scatter plots:
#
# 1. There seem to be a correlation between the popularity and vote count (in the first graph) which will explain why the movie with the highest popularity made had the highest vote count and vice versa.
#
#
# 2. There seem to be a correlation between the budget and revenue (in the second graph) which will explain why the movie with the highest budget made the most revenue and vice versa as plotted in the pie chart.

# %% [markdown]
# # 6. Limitations & Further Improvements

# %% [markdown]
# 1. The data set contained chinese symbols which could not be read by the notebook. This is why the most popular movie contains certain characters. In future, I seek to expand my knowledge on using libraries to make other languages readable or better still, knowing how to better clean data containg such characters.
#
#
# 2. More questions popped up when performing the analysis. Like: Do the actors, production companies or director play a key role in the popularity of the data? This could not be answered as the data collected was limited to just the popularity of the movie. In future, I seek to obtain data that asks viewers whether or not they consider the actors, production companies or movie directors when watching or voting for the movie.
#
#
# 3. There is no way to identify if the popularity of the movie is based on the number of people who watch it or people just voted.

# %% [markdown]
# # 7. References
#
# 1. https://chartio.com/learn/charts/what-is-a-scatter-plot/
#
#
# 2. https://numpy.org/doc/stable/reference/generated/numpy.average.html
#
#
# 3. https://www.statalist.org/forums/forum/general-stata-discussion/general/1406515-failed-to-unicode-translate-the-chinese-character-string-to-stata14-format
#
#
# 4. https://codersdaily.in/courses/pandas/Cleaning-Strings-in-Pandas#:~:text=One%20of%20the%20most%20helpful%20things%20about%20pandas,it%20directly%20to%20an%20entire%20array%20of%20data.
#
#
# 5. https://stackoverflow.com/questions/43768023/remove-characters-from-pandas-column
